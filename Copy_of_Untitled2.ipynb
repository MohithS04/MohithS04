# %% [markdown]
# <a href="https://colab.research.google.com/github/MohithS04/MohithS04/blob/main/Copy_of_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

# %%
iris=load_iris()

# %%
x=iris.data
y=iris.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
sc=StandardScaler()

# %%
sc.fit(x_train)
x_train_std=sc.transform(x_train)

# %%
x_test_std=sc.transform(x_test)
x_test[0:5]
x_test_std[0:5]
# Out:
# array([[ 0.3100623 , -0.50256349,  0.484213  , -0.05282593],
#        [-0.17225683,  1.89603497, -1.26695916, -1.27039917],
#        [ 2.23933883, -0.98228318,  1.76840592,  1.43531914],
#        [ 0.18948252, -0.26270364,  0.36746819,  0.35303182],
#        [ 1.15412078, -0.50256349,  0.54258541,  0.2177459 ]])

# %%
plt.scatter(x[:,0],x[:,3],c=y,cmap='flag')
plt.xlabel('Sepal Length cm')
plt.ylabel('Petal Width cm')
plt.show()
